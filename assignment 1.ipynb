# %%
##Q1 Explain the difference between the following data types with examples: 
#Integer (int)  
#Float (float)  
#String (str)  
# Boolean (bool)
 

#integer data type:>>>>> It cantains only without decimal value and cannot contain decimal point
#example<<<
n=2
a=34
print(n)
print(type(a)) 

##Float data type:<<< IT contains decimal value and its data type "float"
# example:<<<
a=1.2
print(a)
print(type(a))  


##string data type:>>>>It is a sequence of characters enclosed in quotes..it used for represented text data .. and we can access individual character in index value
# example:<<<<
a="today"
print(a) 
print(type(a))

##Boolean data type:>>>>IT represent logical value. there are only two possibkle values:"True"&&"False" And its data type "bool"
#example :<<<
a = True
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>
# 1.2
# <class 'float'>
# today
# <class 'str'>
# True
# <class 'bool'>

# %%
#Q2  Write a Python program to create three variables: 
#name  
#age  
# city  
#Store your details in them and print the values. 
#Sample Output: Name: Gargi 
#Age: 20 
#City: Jaipur 

name="Prikshit"
age=18
city="Pilani"

print("Name is :" ,name)
print("Age:", age)
print("City:", city)
# Out:
# Name is : Prikshit
# Age: 18
# City: Pilani

# %%
#Q3 Write a Python program that: 
#Takes a user's name as input.  
#Prints the name in uppercase.  
#Prints the total number of characters in the name

#code:<<<
name=input("Enter your name")
a=name.upper()
print(a)


print(len(name))
# Out:
# VIVAN
# 5

# %%
##Q4 Explain any five commonly used string methods in Python with example
#>>string indexing<<<<
n="python"
print(n[3])

#<<<string slicing>>>
n="python"
print(n[1:3])

#<<string upper and loqwer case>>>
n="hello"
a=n.upper()
print(a)

##
n="HELLO"
a=n.lower()
print(a)

#<<<<<string replace>>>
n="HELLO"
a=n.replace("HELLO","hii")
print(a)

#<<<string startswith and endswith>>>
n="python"
a=n.startswith("p")
print(a)
b=n.endswith("y")
print(b)
# Out:
# h
# yt
# HELLO
# hello
# hii
# True
# False

# %%
# Q5 Create a list containing the names of five fruits. 
#• Print the complete list.  
#• Print the first and last element.  
#• Print the total number of items in the list.

#code<<<
a=["mango","apple","orange","banana","kiwi"]
print(a)
print(a[0])
print(a[4])
print(len(a))
# Out:
# ['mango', 'apple', 'orange', 'banana', 'kiwi']
# mango
# kiwi
# 5

# %%
# Q6 Write a Python program to: 
#• Create a list of numbers [10, 20, 30, 40, 50]  
#• Add 60 to the list.  
#• Remove 20 from the list.  
#• Print the updated list. 

 #code<<
a=[10,20,30,40,50]
b=a.append(60)
print(a)
c=a.pop(1)
print(a)
print("updated list:",a)

d=a.remove(30)
print(a)

print(a.clear())
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 30, 40, 50, 60]
# updated list: [10, 30, 40, 50, 60]
# [10, 40, 50, 60]
# None

# %%
#Q7 What is Artificial Intelligence (AI)? Explain its importance and mention any four real-life applications of AI.
"""Artificial Intelligence (AI) is a branch of Computer Science that focuses on creating machines and computer systems capable of performing tasks that normally require human intelligence. These tasks include learning, reasoning, problem-solving, understanding language, recognizing patterns, and making decisions.
"""
#>>>Importance of AI
"""
AI is important because it:

>>> Automates repetitive tasks, increasing efficiency and productivity.

>>> Processes large amounts of data quickly and accurately.

>>> Improves decision-making through data analysis and predictions.

>>> Reduces human errors in many applications.

>>> Enhances innovation in fields such as healthcare, education, transportation, and business.
"""
#>>>>>Four Real-Life Applications of AI
"""
>>> Healthcare
AI helps doctors diagnose diseases, analyze medical images, and recommend treatments.
Example: AI-assisted detection of cancer from medical scans.

>>> Virtual Assistants
AI powers voice assistants that understand and respond to user commands.
Examples include Siri and Google Assistant.

>>> Transportation
AI is used in navigation systems, traffic management, and self-driving vehicles.
Example: Tesla uses AI in its driver-assistance systems.


>>> E-commerce and Recommendations
AI recommends products based on customer preferences and browsing history.
Examples include recommendations on Amazon and Netflix.
"""
# Out:
# '\n>>> Healthcare\nAI helps doctors diagnose diseases, analyze medical images, and recommend treatments.\nExample: AI-assisted detection of cancer from medical scans.\n\n>>> Virtual Assistants\nAI powers voice assistants that understand and respond to user commands.\nExamples include Siri and Google Assistant.\n\n>>> Transportation\nAI is used in navigation systems, traffic management, and self-driving vehicles.\nExample: Tesla uses AI in its driver-assistance systems.\n\n\n>>> E-commerce and Recommendations\nAI recommends products based on customer preferences and browsing history.\nExamples include recommendations on Amazon and Netflix.\n'

# %%
#Q8 Identify whether the following are examples of AI and explain why:
""" 
• ChatGPT  
• Google Maps route prediction  
• Calculator  
• Netflix recommendations  
• Voice assistants (Alexa/Siri)
"""

"""
#chatGPT(Ai tool)>>>>>:It uses artificial intelligence to understand language, answer questions, and generate human-like responses.

#Google Maps route prediction(Ai tool)>>>>: It analyzes traffic data, user behavior, and road conditions to predict the best routes and travel times.

#Calculator(Not Ai)>>>>: It performs calculations based on fixed rules and formulas. It does not learn from data or make decisions.

#Netflix recommendations(Ai tool)>>>>>: It uses AI algorithms to suggest movies and shows based on a user's viewing history and preferences.

#Voice assistants(Ai tool)>>>>>: They use speech recognition and natural language processing to understand and respond to voice commands.
"""
# Out:
# "\n#chatGPT(Ai tool)>>>>>:It uses artificial intelligence to understand language, answer questions, and generate human-like responses.\n\n#Google Maps route prediction(Ai tool)>>>>: It analyzes traffic data, user behavior, and road conditions to predict the best routes and travel times.\n\n#Calculator(Not Ai)>>>>: It performs calculations based on fixed rules and formulas. It does not learn from data or make decisions.\n\n#Netflix recommendations(Ai tool)>>>>>: It uses AI algorithms to suggest movies and shows based on a user's viewing history and preferences.\n\n#Voice assistants(Ai tool)>>>>>: They use speech recognition and natural language processing to understand and respond to voice commands.\n"
